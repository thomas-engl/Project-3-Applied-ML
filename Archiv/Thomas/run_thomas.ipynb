# %%
from functions_thomas import *

# %%
plots_pinn_pde_complex_rhs(np_seed = 238, torch_seed = 301, times = [0.01,0.1])
# Out:
# /workspaces/Project-3-Applied-ML/Archiv/Thomas/functions_thomas.py:34: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   x_colloc = torch.tensor(xs, dtype=torch.float32).view(-1,1)
# /workspaces/Project-3-Applied-ML/Archiv/Thomas/functions_thomas.py:35: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   t_colloc = torch.tensor(ts, dtype=torch.float32).view(-1,1)
# Epoch 0, Loss: 89.809654, MSE: 0.204339
# Epoch 50, Loss: 72.093391, MSE: 0.207498
# Epoch 100, Loss: 67.990234, MSE: 0.191626
# Epoch 150, Loss: 65.586662, MSE: 0.184552
# Epoch 200, Loss: 63.919636, MSE: 0.178301
# Epoch 250, Loss: 61.921181, MSE: 0.170960
# Epoch 300, Loss: 60.230637, MSE: 0.164757
# Epoch 350, Loss: 58.655514, MSE: 0.159432
# Epoch 400, Loss: 57.366669, MSE: 0.154655
# Epoch 450, Loss: 56.168549, MSE: 0.149912
# Epoch 500, Loss: 54.977562, MSE: 0.145289
# Epoch 550, Loss: 57.252308, MSE: 0.146465
# Epoch 600, Loss: 49.164711, MSE: 0.123605
# Epoch 650, Loss: 44.038673, MSE: 0.083577
# Epoch 700, Loss: 28.640572, MSE: 0.049039
# Epoch 749, Loss: 9.112324, MSE: 0.012833
# Epoch 0, Loss: 1.643445, MSE: 0.000540
# Epoch 1, Loss: 0.281906, MSE: 0.000021
# Epoch 2, Loss: 0.015762, MSE: 0.000002
# Epoch 3, Loss: 0.003614, MSE: 0.000000
# Epoch 4, Loss: 0.001505, MSE: 0.000000
# Epoch 5, Loss: 0.000793, MSE: 0.000000
# Epoch 6, Loss: 0.000438, MSE: 0.000000
# Epoch 7, Loss: 0.000291, MSE: 0.000000
# Epoch 8, Loss: 0.000210, MSE: 0.000000
# Epoch 9, Loss: 0.000151, MSE: 0.000000
# L^2 error:         4.2447344e-05
# L_^{infty}_error:  0.0002940297

# %%
analyze_different_learning_rates_adam(np_seed = 23, torch_seed = 30, learning_rates =[0.0001, 0.001, 0.01, 0.1, 1], epochs =1000)
# Out:
# /workspaces/Project-3-Applied-ML/Archiv/Thomas/functions_thomas.py:109: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   x_colloc = torch.tensor(xs, dtype=torch.float32).view(-1,1)
# /workspaces/Project-3-Applied-ML/Archiv/Thomas/functions_thomas.py:110: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   t_colloc = torch.tensor(ts, dtype=torch.float32).view(-1,1)
# L inf best constant tensor(1.2970)
# list_l2errors_train_lr=[np.float32(0.20375709), np.float32(0.19937956), np.float32(0.13832961), np.float32(0.20057711), np.float32(0.20057711)]
# list_linf_errors_train_lr=[np.float32(1.3885435), np.float32(1.3530434), np.float32(0.79178274), np.float32(0.7827755), np.float32(0.7827755)]
# list_l2errors_test_lr=[np.float32(0.2153407), np.float32(0.21053985), np.float32(0.14158544), np.float32(0.20865868), np.float32(0.20865868)]
# list_linf_errors_test_lr=[np.float32(1.3659453), np.float32(1.3311415), np.float32(0.7915472), np.float32(0.78302443), np.float32(0.78302443)]

# %%
epochs_plot(238, 301)
# Out:
# /workspaces/Project-3-Applied-ML/Archiv/Thomas/functions_thomas.py:241: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   x_colloc = torch.tensor(xs, dtype=torch.float32).view(-1,1)
# /workspaces/Project-3-Applied-ML/Archiv/Thomas/functions_thomas.py:242: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   t_colloc = torch.tensor(ts, dtype=torch.float32).view(-1,1)
# Epoch 0, Loss: 89.809654, MSE: 0.204339
# Epoch 50, Loss: 72.093391, MSE: 0.207498
# Epoch 100, Loss: 67.990234, MSE: 0.191626
# Epoch 150, Loss: 65.586662, MSE: 0.184552
# Epoch 200, Loss: 63.919636, MSE: 0.178301
# Epoch 250, Loss: 61.921181, MSE: 0.170960
# Epoch 300, Loss: 60.230637, MSE: 0.164757
# Epoch 350, Loss: 58.655514, MSE: 0.159432
# Epoch 400, Loss: 57.366669, MSE: 0.154655
# Epoch 450, Loss: 56.168549, MSE: 0.149912
# Epoch 500, Loss: 54.977562, MSE: 0.145289
# Epoch 550, Loss: 57.252308, MSE: 0.146465
# Epoch 600, Loss: 49.164711, MSE: 0.123605
# Epoch 650, Loss: 44.038673, MSE: 0.083577
# Epoch 700, Loss: 28.640572, MSE: 0.049039
# Epoch 749, Loss: 9.112324, MSE: 0.012833
# Epoch 0, Loss: 1.643445, MSE: 0.000540
# Epoch 1, Loss: 0.281906, MSE: 0.000021
# Epoch 2, Loss: 0.015762, MSE: 0.000002
# Epoch 3, Loss: 0.003614, MSE: 0.000000
# Epoch 4, Loss: 0.001505, MSE: 0.000000
# Epoch 5, Loss: 0.000793, MSE: 0.000000
# Epoch 6, Loss: 0.000438, MSE: 0.000000
# Epoch 7, Loss: 0.000291, MSE: 0.000000
# Epoch 8, Loss: 0.000210, MSE: 0.000000
# Epoch 9, Loss: 0.000151, MSE: 0.000000

# %%
analyze_regularization(np_seed=1228, torch_seed = 872, weights = np.concatenate(([0.0], np.logspace(-4, 1, 5))))
# Out:
# Testing weight decay: 0.0
#   Attempt 1 for weight 0.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 analyze_regularization(np_seed=1228, torch_seed = 872, weights = np.concatenate(([0.0], np.logspace(-4, 1, 5))))
#
# File /workspaces/Project-3-Applied-ML/Archiv/Thomas/functions_thomas.py:259, in analyze_regularization(np_seed, torch_seed, weights)
#     257 # === training ===
#     258 pde_nn.train(lr=1e-2, weight_decay=0.0, epochs=epochs_adam, opt_time_scale=True, print_epochs=0)
# --> 259 pde_nn.train_lbfgs(lr=1, opt_time_scale=True, epochs=epochs_lbfgs, max_iter=iter_lbfgs, print_epochs=0)
#     261 # === evaluate ===
#     262 err = pde_nn.L_2_error(x_test, t_test)
#
# File /workspaces/Project-3-Applied-ML/Archiv/Thomas/heat_612.py:249, in heat_nn.train_lbfgs(self, lr, opt_time_scale, epochs, max_iter, print_epochs, save_losses, damping)
#     246         torch.nn.utils.clip_grad_norm_(self.net.parameters(), 1.0)
#     247     return loss
# --> 249 optimizer.step(closure)
#     253 if save_losses:
#     254     losses.append(self.loss_fn().item())
#
# File /dolfinx-env/lib/python3.12/site-packages/torch/optim/optimizer.py:517, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     512         else:
#     513             raise RuntimeError(
#     514                 f"{func} must return None or a tuple of (new_args, new_kwargs), but got {result}."
#     515             )
# --> 517 out = func(*args, **kwargs)
#     518 self._optimizer_step_code()
#     520 # call optimizer step post hooks
#
# File /dolfinx-env/lib/python3.12/site-packages/torch/utils/_contextlib.py:120, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     117 @functools.wraps(func)
#     118 def decorate_context(*args, **kwargs):
#     119     with ctx_factory():
# --> 120         return func(*args, **kwargs)
#
# File /dolfinx-env/lib/python3.12/site-packages/torch/optim/lbfgs.py:459, in LBFGS.step(self, closure)
#     457     loss = closure()
#     458 loss = float(loss)
# --> 459 flat_grad = self._gather_flat_grad()
#     460 opt_cond = flat_grad.abs().max() <= tolerance_grad
#     461 ls_func_evals = 1
#
# File /dolfinx-env/lib/python3.12/site-packages/torch/optim/lbfgs.py:262, in LBFGS._gather_flat_grad(self)
#     255         self._numel_cache = sum(
#     256             2 * p.numel() if torch.is_complex(p) else p.numel()
#     257             for p in self._params
#     258         )
#     260     return self._numel_cache
# --> 262 def _gather_flat_grad(self):
#     263     views = []
#     264     for p in self._params:
#
# KeyboardInterrupt:

# %%
analyze_activation_funcs(np_seed=123, torch_seed = 34)
