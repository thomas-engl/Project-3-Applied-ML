# %%
import sys
print(sys.version)
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
print(tf.config.list_physical_devices())
print(tf.__version__)
# Out:
# 3.12.11 (main, Jul 22 2025, 04:27:29) [GCC 10.2.1 20210110]
# 2025-11-13 00:25:29.694629: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')]
# 2.20.0
# 2025-11-13 00:25:34.430479: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)

# %%
x = tf.random.normal((100, 5))
